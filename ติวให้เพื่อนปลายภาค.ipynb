# %% [markdown]
# <a href="https://colab.research.google.com/github/MOOwuttichai/python_dataviz2023/blob/main/%E0%B8%95%E0%B8%B4%E0%B8%A7%E0%B9%83%E0%B8%AB%E0%B9%89%E0%B9%80%E0%B8%9E%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%99%E0%B8%9B%E0%B8%A5%E0%B8%B2%E0%B8%A2%E0%B8%A0%E0%B8%B2%E0%B8%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #วิธีการหาโค้ดในเน็ต
# หาจากคำว่า "เราต้องการทำอะไร"+python(+datatyerที่เราอยากใช้)

# %% [markdown]
# ## import library python

# %%
import pandas as pd

# %% [markdown]
# #วิธีการเปิด csv execl

# %%
df = pd.read_excel('/content/drive/MyDrive/ติวเพื่อน 2023 อ.ต้น/ectreport2023_มีภาค.xlsx')
region = pd.read_excel('/content/drive/MyDrive/ติวเพื่อน 2023 อ.ต้น/ectreport2023_มีภาค.xlsx',sheet_name=1)
result_constituencies_PartyList = pd.read_excel('/content/drive/MyDrive/ติวเพื่อน 2023 อ.ต้น/ectreport2023_มีภาค.xlsx',sheet_name=2)
result_constituencies_Candidate = pd.read_excel('/content/drive/MyDrive/ติวเพื่อน 2023 อ.ต้น/ectreport2023_มีภาค.xlsx',sheet_name=3)
result_constituencies_status = pd.read_excel('/content/drive/MyDrive/ติวเพื่อน 2023 อ.ต้น/ectreport2023_มีภาค.xlsx',sheet_name=4)
info_province = pd.read_excel('/content/drive/MyDrive/ติวเพื่อน 2023 อ.ต้น/ectreport2023_มีภาค.xlsx',sheet_name=5)
info_party_overview = pd.read_excel('/content/drive/MyDrive/ติวเพื่อน 2023 อ.ต้น/ectreport2023_มีภาค.xlsx',sheet_name=6)
info_constituency = pd.read_excel('/content/drive/MyDrive/ติวเพื่อน 2023 อ.ต้น/ectreport2023_มีภาค.xlsx',sheet_name=7)
Candidate_Constituency = pd.read_excel('/content/drive/MyDrive/ติวเพื่อน 2023 อ.ต้น/ectreport2023_มีภาค.xlsx',sheet_name=8)
Candidate_PartyList = pd.read_excel('/content/drive/MyDrive/ติวเพื่อน 2023 อ.ต้น/ectreport2023_มีภาค.xlsx',sheet_name=9)
Candidate_PM = pd.read_excel('/content/drive/MyDrive/ติวเพื่อน 2023 อ.ต้น/ectreport2023_มีภาค.xlsx',sheet_name=10)

# %%
region
# Out:
#   region_id            region_name
# 0       R01               ภาคเหนือ
# 1       R02  ภาคตะวันออกเฉียงเหนือ
# 2       R03                ภาคกลาง
# 3       R04                 ภาคใต้
# 4       R05             ภาคตะวันตก
# 5       R06            ภาคตะวันออก

# %%
for_thai = pd.read_csv('/content/drive/MyDrive/ติวเพื่อน 2023 อ.ต้น/creditcard_2023.csv',index_col = 0)

# %%
x = for_thai.head()

# %% [markdown]
# #วิธีการดูข้อมูลเบื้องต้น

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      5 non-null      float64
#  1   V2      5 non-null      float64
#  2   V3      5 non-null      float64
#  3   V4      5 non-null      float64
#  4   V5      5 non-null      float64
#  5   V6      5 non-null      float64
#  6   V7      5 non-null      float64
#  7   V8      5 non-null      float64
#  8   V9      5 non-null      float64
#  9   V10     5 non-null      float64
#  10  V11     5 non-null      float64
#  11  V12     5 non-null      float64
#  12  V13     5 non-null      float64
#  13  V14     5 non-null      float64
#  14  V15     5 non-null      float64
#  15  V16     5 non-null      float64
#  16  V17     5 non-null      float64
#  17  V18     5 non-null      float64
#  18  V19     5 non-null      float64
#  19  V20     5 non-null      float64
#  20  V21     5 non-null      float64
# ...

# %%
x.describe()
# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# count  5.000000  5.000000  5.000000  5.000000  5.000000  5.000000  5.000000
# mean   0.021042 -0.489863  1.611351 -0.501967  0.167299  0.850969  0.569222
# std    0.540789  0.289480  0.694928  0.364336  0.090375  0.419426  0.132303
# min   -0.260648 -0.949385  0.558056 -1.090178  0.074062  0.428605  0.406466
# 25%   -0.260272 -0.508959  1.527053 -0.457986  0.106125  0.530549  0.518269
# 50%   -0.206820 -0.469648  1.728538 -0.448293  0.129681  0.732898  0.519014
# 75%   -0.152152 -0.356045  1.746840 -0.429654  0.249486  1.143312  0.658849
# max    0.985100 -0.165280  2.496266 -0.083724  0.277140  1.419481  0.743511
#
#              V8        V9       V10  ...       V21       V22       V23  \
# count  5.000000  5.000000  5.000000  ...  5.000000  5.000000  5.000000
# mean  -0.127298  0.331508  0.680305  ... -0.112884  0.201253  0.102801
# ...

# %%
result_constituencies_Candidate.describe()
# Out:
#        mp_app_rank   mp_app_vote  mp_app_vote_percent     party_id
# count  4781.000000   4781.000000          4781.000000  4781.000000
# mean      6.711985   7654.289898             8.223124   733.349090
# std       3.845837  12389.868008            19.185614    23.968199
# min       1.000000      0.000000             0.000000   701.000000
# 25%       3.000000    300.000000             0.309190   709.000000
# 50%       6.000000    780.000000             0.809330   729.000000
# 75%      10.000000  11738.000000            12.227910   762.000000
# max      20.000000  63185.000000           714.909760   786.000000

# %% [markdown]
# #วิธีดู datafame แบบมีเงื่อนไข

# %%
result_constituencies_Candidate[result_constituencies_Candidate['mp_app_vote_percent'] > 100]
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 2593   NST_6   NST_6_1            5         5596            146.37719
# 2594   NST_6  NST_6_10            4         7731            202.22338
# 2601   NST_6   NST_6_4            6         5574            145.80173
# 2602   NST_6   NST_6_5            1        27331            714.90976
# 2605   NST_6   NST_6_8            3        10700            279.88491
# 2606   NST_6   NST_6_9            2        23260            608.42270
#
#       party_id
# 2593       705
# 2594       763
# 2601       701
# 2602       743
# 2605       726
# 2606       709

# %% [markdown]
# #วิธีดูค่า null เเทนค่า null

# %%
info_party_overview.isnull().any()
# Out:
# id          False
# party_no     True
# name        False
# abbr        False
# color       False
# logo_url    False
# dtype: bool

# %% [markdown]
# #วิธี dropna

# %%
print(info_party_overview.shape)
info_party_overview.dropna()
# Out:
# (70, 6)
#      id  party_no           name    abbr    color  \
# 0   701      26.0   ประชาธิปัตย์    ปชป.  #06aff3
# 1   702      63.0     ประชากรไทย    ปชท.  #0f41ce
# 2   703      60.0   ความหวังใหม่    ควม.  #e6b750
# 3   705      29.0       เพื่อไทย     พท.  #da3731
# 4   706      14.0  ชาติพัฒนากล้า    ชพก.  #233e8a
# ..  ...       ...            ...     ...      ...
# 65  780      55.0    ไทยก้าวหน้า    ทกน.  #b9bee3
# 66  781       9.0           พลัง      พ.  #8e8fc7
# 67  783      52.0  ชาติรุ่งเรือง    ชรร.  #9cb4c9
# 68  784      23.0       รวมใจไทย  ร.จ.ท.  #eec49a
# 69  786      20.0        เปลี่ยน      ป.  #cc898a
#
#                                              logo_url
# 0   https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1   https://cdn.ectreport.com/images/logos/ประชากร...
# 2   https://cdn.ectreport.com/images/logos/ความหวั...
# 3   https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4   https://cdn.ectreport.com/images/logos/ชาติพัฒ...
# ...

# %%
info_party_overview[info_party_overview['party_no'].isnull()]
# Out:
#      id  party_no          name  abbr    color  \
# 9   711       NaN  ประชาสามัคคี   ปส.  #ecb55e
# 11  713       NaN     พลังบูรพา   พบ.  #4696d6
# 17  720       NaN     รักษ์ธรรม  ร.ธ.  #dbdc9c
#
#                                              logo_url
# 9   https://cdn.ectreport.com/images/logos/ประชาสา...
# 11  https://cdn.ectreport.com/images/logos/พลังบูร...
# 17  https://cdn.ectreport.com/images/logos/รักษ์ธร...

# %% [markdown]
# #วิธี fillna

# %%
fill_na_sasa = info_party_overview.fillna('99')

# %%
fill_na_sasa[fill_na_sasa['party_no']=='99']
# Out:
#      id party_no          name  abbr    color  \
# 9   711       99  ประชาสามัคคี   ปส.  #ecb55e
# 11  713       99     พลังบูรพา   พบ.  #4696d6
# 17  720       99     รักษ์ธรรม  ร.ธ.  #dbdc9c
#
#                                              logo_url
# 9   https://cdn.ectreport.com/images/logos/ประชาสา...
# 11  https://cdn.ectreport.com/images/logos/พลังบูร...
# 17  https://cdn.ectreport.com/images/logos/รักษ์ธร...

# %% [markdown]
# #วิธีการ marge and join

# %%
con_id1 = result_constituencies_Candidate[result_constituencies_Candidate['cons_id']=='ACR_1']
con_id2 = result_constituencies_Candidate[result_constituencies_Candidate['cons_id']=='ACR_2']
con_id3 = result_constituencies_Candidate[result_constituencies_Candidate['cons_id']=='AYA_1']

# %%
con_id1
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0    ACR_1   ACR_1_1            9          459              0.43477       706
# 1    ACR_1  ACR_1_10            1        38275             36.25419       709
# 2    ACR_1  ACR_1_11           13          126              0.11935       712
# 3    ACR_1  ACR_1_12           12          127              0.12029       742
# 4    ACR_1  ACR_1_13           11          212              0.20081       761
# 5    ACR_1   ACR_1_2           10          234              0.22165       769
# 6    ACR_1   ACR_1_3            6         2701              2.55840       763
# 7    ACR_1   ACR_1_4            8          668              0.63273       719
# 8    ACR_1   ACR_1_5            4        15926             15.08515       701
# 9    ACR_1   ACR_1_6            3        16724             15.84102       726
# 10   ACR_1   ACR_1_7            7         1281              1.21337       762
# ...

# %%
con_id2
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 13   ACR_2   ACR_2_1            2        19188             17.16080       726
# 14   ACR_2  ACR_2_10            1        46881             41.92804       709
# 15   ACR_2  ACR_2_11           11          193              0.17261       742
# 16   ACR_2  ACR_2_12           12          173              0.15472       770
# 17   ACR_2   ACR_2_2            6         2027              1.81285       762
# 18   ACR_2   ACR_2_3            3        17637             15.77366       705
# 19   ACR_2   ACR_2_4           10          197              0.17619       712
# 20   ACR_2   ACR_2_5            5         2530              2.26271       701
# 21   ACR_2   ACR_2_6            8          519              0.46417       719
# 22   ACR_2   ACR_2_7            7         1156              1.03387       763
# 23   ACR_2   ACR_2_8            9          378              0.33806       769
# ...

# %%
ไตเติ้ล_contest = pd.concat([con_id1, con_id3])

# %%
ไตเติ้ล_contest
# Out:
#    cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0    ACR_1   ACR_1_1            9          459              0.43477       706
# 1    ACR_1  ACR_1_10            1        38275             36.25419       709
# 2    ACR_1  ACR_1_11           13          126              0.11935       712
# 3    ACR_1  ACR_1_12           12          127              0.12029       742
# 4    ACR_1  ACR_1_13           11          212              0.20081       761
# 5    ACR_1   ACR_1_2           10          234              0.22165       769
# 6    ACR_1   ACR_1_3            6         2701              2.55840       763
# 7    ACR_1   ACR_1_4            8          668              0.63273       719
# 8    ACR_1   ACR_1_5            4        15926             15.08515       701
# 9    ACR_1   ACR_1_6            3        16724             15.84102       726
# 10   ACR_1   ACR_1_7            7         1281              1.21337       762
# ...

# %% [markdown]
# ```ตารางซ้าย.merge(ตารางขวา,left_on='colunmที่เป็น Keyเชื่อม',right_on='colunmที่เป็น Keyเชื่อม',how='left')```

# %%
x1=con_id1.merge(Candidate_Constituency, on='mp_app_id',how='left')

# %% [markdown]
# #วิธีการลบคำซ้ำ

# %%
x2=x1.merge(info_constituency, on='cons_id',how='left')

# %%
x3 = x2[['cons_id','mp_app_id','party_id','mp_app_name','mp_app_vote','mp_app_vote_percent']]

# %%
x3
# Out:
#    cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0    ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 2    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 4    ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 6    ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 8    ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 10   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# 12   ACR_1   ACR_1_3       763        นายบวรศักดิ์ คณาเสน         2701
# 14   ACR_1   ACR_1_4       719       นายอิทธิกร สุวะมาตย์          668
# 16   ACR_1   ACR_1_5       701  นางสาวแป้งธนชาภา จันทวารา        15926
# 18   ACR_1   ACR_1_6       726          นายประภาส เวชกรณ์        16724
# 20   ACR_1   ACR_1_7       762           นายทวีชัย พลธานี         1281
# 22   ACR_1   ACR_1_8       705          นางสมหญิง บัวบุตร        21388
# ...

# %%
# making a bool series
bool_series = x3.duplicated(subset='mp_app_name')
# passing NOT of bool series to see unique values only
x4 = x3[~bool_series]
# displaying data
x5 = x4.reset_index()

# %%
x5
# Out:
#     index cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0       0   ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 1       2   ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 2       4   ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 3       6   ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 4       8   ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 5      10   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# 6      12   ACR_1   ACR_1_3       763        นายบวรศักดิ์ คณาเสน         2701
# 7      14   ACR_1   ACR_1_4       719       นายอิทธิกร สุวะมาตย์          668
# 8      16   ACR_1   ACR_1_5       701  นางสาวแป้งธนชาภา จันทวารา        15926
# 9      18   ACR_1   ACR_1_6       726          นายประภาส เวชกรณ์        16724
# 10     20   ACR_1   ACR_1_7       762           นายทวีชัย พลธานี         1281
# ...

# %%
bool_series = x3['mp_app_name'].duplicated(keep = False)
# passing NOT of bool series to see unique values only
x6 = x3[~bool_series]
# displaying data
x6.info()
x6
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cons_id              13 non-null     object
#  1   mp_app_id            13 non-null     object
#  2   party_id             13 non-null     int64
#  3   mp_app_name          13 non-null     object
#  4   mp_app_vote          13 non-null     int64
#  5   mp_app_vote_percent  13 non-null     float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 728.0+ bytes
#    cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0    ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 2    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 4    ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 6    ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# ...

# %% [markdown]
# #วิธีการสร้าง datafame เเละ เพิ่มcolumn

# %%
y ={
    'LOL' : ['sc','sa','si','gh','jk','lg','fg','jg','kn','lj','fd','ng','kl']
}

# %%
lol = pd.DataFrame(y)
lol
# Out:
#    LOL
# 0   sc
# 1   sa
# 2   si
# 3   gh
# 4   jk
# 5   lg
# 6   fg
# 7   jg
# 8   kn
# 9   lj
# 10  fd
# 11  ng
# 12  kl

# %%
xlol = x5.join(lol,how ='left')

# %%
xlol
# Out:
#     index cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0       0   ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 1       2   ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 2       4   ACR_1  ACR_1_11       712        นายการันต์ ลุนพันธ์          126
# 3       6   ACR_1  ACR_1_12       742             นายไสว ผลาวงศ์          127
# 4       8   ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# 5      10   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# 6      12   ACR_1   ACR_1_3       763        นายบวรศักดิ์ คณาเสน         2701
# 7      14   ACR_1   ACR_1_4       719       นายอิทธิกร สุวะมาตย์          668
# 8      16   ACR_1   ACR_1_5       701  นางสาวแป้งธนชาภา จันทวารา        15926
# 9      18   ACR_1   ACR_1_6       726          นายประภาส เวชกรณ์        16724
# 10     20   ACR_1   ACR_1_7       762           นายทวีชัย พลธานี         1281
# ...

# %% [markdown]
# #loop ifelse def groupby max min mean count sum

# %%
ไตเติ้ล_contest.groupby('cons_id')[['mp_app_vote','mp_app_id']].count().reset_index().sort_values(by = 'mp_app_vote',ascending = False)
# Out:
#   cons_id  mp_app_vote  mp_app_id
# 0   ACR_1           13         13
# 1   AYA_1           10         10

# %%
k[0]
# Out:
# 'I'

# %%
k =['I','Love','you']
for i in range(len(k)):
  a = k[i]

# %%
range(len(k))
# Out:
# range(0, 3)

# %% [markdown]
# #quiz เราต้องการสร้างรายชื่อ สส. ของเเต่ละเขต
# โดยต้องการทราบ รหัสเขต ชื่อสส. จังหวัดที่เขาอยู่ พรรรคที่สังกัด คะเเนนเสียง เปอร์เซ็น
